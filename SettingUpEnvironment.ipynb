# %%
pip install -r requirements.txt --no-index --find-links file:///tmp/packages
# Out:
# ERROR: dlib-19.18.0-cp37-cp37m-linux_x86_64.whl is not a supported wheel on this platform.

# %%
# !pip install tesseract-ocr
# Out:
# ...
#   Using cached tesseract-ocr-0.0.1.tar.gz (33 kB)
# ...
#   Running setup.py clean for tesseract-ocr
# Failed to build tesseract-ocr
# ...
#     Running setup.py install for tesseract-ocr: started
#     Running setup.py install for tesseract-ocr: finished with status 'error'
#   ERROR: Command errored out with exit status 1:
#    command: 'C:\Users\guppr\anaconda3\python.exe' -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\guppr\\AppData\\Local\\Temp\\pip-install-uy45ah10\\tesseract-ocr\\setup.py'"'"'; __file__='"'"'C:\\Users\\guppr\\AppData\\Local\\Temp\\pip-install-uy45ah10\\tesseract-ocr\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d 'C:\Users\guppr\AppData\Local\Temp\pip-wheel-_zmd5in3'
#        cwd: C:\Users\guppr\AppData\Local\Temp\pip-install-uy45ah10\tesseract-ocr\
#   Complete output (8 lines):
#   running bdist_wheel
# ...

# %%
# !pip install --record 'C:\Users\guppr\AppData\Local\Temp\pip-record-5gw8n8wm\install-record.txt' --single-version-externally-managed --compile --install-headers 'C:\Users\guppr\anaconda3\Include\tesseract-ocr'
# Out:
# Usage:
#   pip install [options] <requirement specifier> [package-index-options] ...
#   pip install [options] -r <requirements file> [package-index-options] ...
#   pip install [options] [-e] <vcs project url> ...
#   pip install [options] [-e] <local project path> ...
#   pip install [options] <archive url/path> ...
#
# no such option: --record

# %%
# !pip install pytesseract
# !pip install tesseract-ocr

# %%
# !pip install pdf2image

# %%
# !pip install -y poppler-utils
# !pip install --upgrade pdf2image
# Out:
# Usage:
#   pip install [options] <requirement specifier> [package-index-options] ...
#   pip install [options] -r <requirements file> [package-index-options] ...
#   pip install [options] [-e] <vcs project url> ...
#   pip install [options] [-e] <local project path> ...
#   pip install [options] <archive url/path> ...
#
# no such option: -y
# Requirement already up-to-date: pdf2image in c:\users\guppr\anaconda3\lib\site-packages (1.16.0)
# ...

# %%
#using OpenCV for image preprocessing

# !pip install opencv-python

# %%
# !pip install -U easynmt
# Out:
# Processing c:\users\guppr\appdata\local\pip\cache\wheels\31\31\eb\e2cf827facbf93f88303e801722b0f897e08c8ed2dee393218\easynmt-2.0.1-py3-none-any.whl
# ...
#   Using cached fasttext-0.9.2.tar.gz (68 kB)
# ...
#   ERROR: Command errored out with exit status 1:
#    command: 'C:\Users\guppr\anaconda3\python.exe' -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\guppr\\AppData\\Local\\Temp\\pip-install-3fw2hdzq\\fasttext\\setup.py'"'"'; __file__='"'"'C:\\Users\\guppr\\AppData\\Local\\Temp\\pip-install-3fw2hdzq\\fasttext\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d 'C:\Users\guppr\AppData\Local\Temp\pip-wheel-mf8d3ig6'
#        cwd: C:\Users\guppr\AppData\Local\Temp\pip-install-3fw2hdzq\fasttext\
#   Complete output (18 lines):
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
# ...

# %%
#Run the following command if you are using pip as your package manager

# !pip install easynet
# Out:
# ...
#   Created wheel for easynet: filename=easynet-0.9-py3-none-any.whl size=3588 sha256=62387e1ad5c461a3e46734a57cc49e125eb0489070d72184d124d9908d905802
#   Stored in directory: c:\users\guppr\appdata\local\pip\cache\wheels\0b\c8\50\c2c2e7464fa2235ba0308070c9beae24bc1e7671a179edcac8
# Successfully built easynet
# ...
# Solving environment: ...working... failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: ...working... failed with repodata from current_repodata.json, will retry with next repodata source.
# ...
# Solving environment: ...working... failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: ...working...
# Found conflicts! Looking for incompatible packages.
# This can take several minutes.  Press CTRL-C to abort.
# failed
# ...
# Examining importlib-metadata:  94%|#########3| 354/377 [18:39<00:08,  2.76it/s]
# ...
# anaconda-navigator -> anaconda-project[version='>=0.4']
# anaconda==2020.11 -> anaconda-project==0.8.4=py_0
#
# ...

# %%
# !pip install --no-deps easynmt
# !pip install tqdm transformers numpy nltk sentencepiece
# Out:
# Processing c:\users\guppr\appdata\local\pip\cache\wheels\31\31\eb\e2cf827facbf93f88303e801722b0f897e08c8ed2dee393218\easynmt-2.0.1-py3-none-any.whl
# ...

# %%
# !pip install Cython

# %%
# !pip uninstall numpy
# !pip install numpy==1.19.3
# Out:
# ^C
# ERROR: Could not install packages due to an EnvironmentError: [WinError 5] Access is denied: 'C:\\Users\\guppr\\anaconda3\\Lib\\site-packages\\~umpy\\core\\_multiarray_tests.cp38-win_amd64.pyd'
# Consider using the `--user` option or check the permissions.
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.19.2
#     Uninstalling numpy-1.19.2:
#       Successfully uninstalled numpy-1.19.2

# %%
# !conda install -c conda-forge poppler
# Out:
# ^C

# %%
# !pip install torchvision
